# %% [markdown]
# # Train a Machine Learning Model to Classify SMSs as Spam or Not Spam
#
# ### Training Dataset (and others) can be found at Kaggle.com
# - **I used a csv dataset from https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset/data which contains a collection of SMSs.**
# - **It contains one set of SMS messages in English of 5,572 messages, tagged acording being ham (legitimate) or spam.**
#
# ### Text Embedding Model: OpenAI's “text-embedding-3-small” model
# - **See https://platform.openai.com/docs/guides/embeddings for more information about their text embedding models.**

# %% [markdown]
# ________________________________________________
# ________________________________________________

# %% [markdown]
# # # Step 1:
# - Import the OpenAI library (you may have to install it first).
# - Download the csv data file from Kaggle (I've already downloaded and saved the csv file (in the same folder as my notebook) as **spam.csv**).
# - Ensure you have an API Key to access OpenAI's text embedding models (I've already created a key).
# - Ensure that you have a credit balance on your OpenAI account.

# %%
# pip install openai
import openai
#I've stored my API key in a separate config.py file. You can comment out the next command in your notebook.
from config import api_key

# %% [markdown]
# _________________________________________
# _________________________________________

# %% [markdown]
# ## Step 2: Import the other libraries needed to train our Spam Classifier
# - You may have to install these libraries if you don't already have them.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# _________________________________
# _________________________________

# %% [markdown]
# ## Step 3: Load the csv data into a dataframe and prepare the data for training the model
# - Load the data into a dataframe. I've called my dataframe 'spam_data'.
# - Inspect the dataframe
# - Do any data cleanup as may be required

# %%
# Load the dataset to inspect it
csv_file = "spam.csv"
spam_data = pd.read_csv(csv_file, encoding='latin-1')

# Display basic information about the dataset and the first few rows to understand its structure
spam_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %% [markdown]
# ### Observations
#
# - v1: Labels indicating whether a message is 'ham' (not spam) or 'spam'.
# - v2: The text of the SMS message itself.
#
# There are also three additional columns (Unnamed: 2, Unnamed: 3, Unnamed: 4) that mostly contain NaN values. These might represent misplaced data or could be artifacts from the dataset formatting.
#
# **Recommendations for Data Preparation:**
# - **Remove Unnecessary Columns:** We should drop the columns Unnamed: 2, Unnamed: 3, and Unnamed: 4 as they contain very little data. It will therefore not be useful information for our task and removing these columns will also simplify our dataset.
# - **Rename Columns:** Renaming v1 to label and v2 to message will make the DataFrame more readable.
# - **Check for Missing Data:** It's good to check if there are any NaN values in the label and message columns that need addressing. In our case, the NaN values are all in the columns we will drop.
# - **Text Normalization:** This is always important. **However, we are not** going to convert text to lowercase, remove punctuation, or eliminate stopwords (you would do this if you are training an embedding model), etc.. OpenAI's models are trained on large datasets that include both lowercase and uppercase text. This makes them robust to different text formats.

# %%
# Cleaning the dataset according to the recommendations above:

# Dropping unnecessary columns
spam_data_cleaned = spam_data.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'])

# Renaming columns
spam_data_cleaned.rename(columns={'v1': 'label', 'v2': 'message'}, inplace=True)

# Check for any NaN values in the label and message columns
nan_counts = spam_data_cleaned.isna().sum()

# Show cleaned dataset and NaN counts
spam_data_cleaned.head(), nan_counts
# Out:
# (  label                                            message
#  0   ham  Go until jurong point, crazy.. Available only ...
#  1   ham                      Ok lar... Joking wif u oni...
#  2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
#  3   ham  U dun say so early hor... U c already then say...
#  4   ham  Nah I don't think he goes to usf, he lives aro...,
#  label      0
#  message    0
#  dtype: int64)

# %% [markdown]
# ### View the cleaned up dataframe contents

# %%
spam_data_cleaned.head(3)
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...

# %% [markdown]
# ### Optional: Change the display style if you want a better visualization of the dataframe

# %%
# Set the maximum width of columns in characters
pd.set_option('display.max_colwidth', None)  # None means no truncation, or you can set a specific large number

# Set the text in DataFrame to be left-aligned
pd.set_option('display.colheader_justify', 'left')

# Apply a style to the DataFrame for left alignment in display
styled_df = spam_data_cleaned.style.set_properties(**{'text-align': 'left'})

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_229a9_row0_col0, #T_229a9_row0_col1, #T_229a9_row1_col0, #T_229a9_row1_col1, #T_229a9_row2_col0, #T_229a9_row2_col1, #T_229a9_row3_col0, #T_229a9_row3_col1, #T_229a9_row4_col0, #T_229a9_row4_col1, #T_229a9_row5_col0, #T_229a9_row5_col1, #T_229a9_row6_col0, #T_229a9_row6_col1, #T_229a9_row7_col0, #T_229a9_row7_col1, #T_229a9_row8_col0, #T_229a9_row8_col1, #T_229a9_row9_col0, #T_229a9_row9_col1, #T_229a9_row10_col0, #T_229a9_row10_col1, #T_229a9_row11_col0, #T_229a9_row11_col1, #T_229a9_row12_col0, #T_229a9_row12_col1, #T_229a9_row13_col0, #T_229a9_row13_col1, #T_229a9_row14_col0, #T_229a9_row14_col1, #T_229a9_row15_col0, #T_229a9_row15_col1, #T_229a9_row16_col0, #T_229a9_row16_col1, #T_229a9_row17_col0, #T_229a9_row17_col1, #T_229a9_row18_col0, #T_229a9_row18_col1, #T_229a9_row19_col0, #T_229a9_row19_col1, #T_229a9_row20_col0, #T_229a9_row20_col1, #T_229a9_row21_col0, #T_229a9_row21_col1, #T_229a9_row22_col0, #T_229a9_row22_col1, #T_229a9_row23_col0, #T_229a9_row23_col1, #T_229a9_row24_col0, #T_229a9_row24_col1, #T_229a9_row25_col0, #T_229a9_row25_col1, #T_229a9_row26_col0, #T_229a9_row26_col1, #T_229a9_row27_col0, #T_229a9_row27_col1, #T_229a9_row28_col0, #T_229a9_row28_col1, #T_229a9_row29_col0, #T_229a9_row29_col1, #T_229a9_row30_col0, #T_229a9_row30_col1, #T_229a9_row31_col0, #T_229a9_row31_col1, #T_229a9_row32_col0, #T_229a9_row32_col1, #T_229a9_row33_col0, #T_229a9_row33_col1, #T_229a9_row34_col0, #T_229a9_row34_col1, #T_229a9_row35_col0, #T_229a9_row35_col1, #T_229a9_row36_col0, #T_229a9_row36_col1, #T_229a9_row37_col0, #T_229a9_row37_col1, #T_229a9_row38_col0, #T_229a9_row38_col1, #T_229a9_row39_col0, #T_229a9_row39_col1, #T_229a9_row40_col0, #T_229a9_row40_col1, #T_229a9_row41_col0, #T_229a9_row41_col1, #T_229a9_row42_col0, #T_229a9_row42_col1, #T_229a9_row43_col0, #T_229a9_row43_col1, #T_229a9_row44_col0, #T_229a9_row44_col1, #T_229a9_row45_col0, #T_229a9_row45_col1, #T_229a9_row46_col0, #T_229a9_row46_col1, #T_229a9_row47_col0, #T_229a9_row47_col1, #T_229a9_row48_col0, #T_229a9_row48_col1, #T_229a9_row49_col0, #T_229a9_row49_col1, #T_229a9_row50_col0, #T_229a9_row50_col1, #T_229a9_row51_col0, #T_229a9_row51_col1, #T_229a9_row52_col0, #T_229a9_row52_col1, #T_229a9_row53_col0, #T_229a9_row53_col1, #T_229a9_row54_col0, #T_229a9_row54_col1, #T_229a9_row55_col0, #T_229a9_row55_col1, #T_229a9_row56_col0, #T_229a9_row56_col1, #T_229a9_row57_col0, #T_229a9_row57_col1, #T_229a9_row58_col0, #T_229a9_row58_col1, #T_229a9_row59_col0, #T_229a9_row59_col1, #T_229a9_row60_col0, #T_229a9_row60_col1, #T_229a9_row61_col0, #T_229a9_row61_col1, #T_229a9_row62_col0, #T_229a9_row62_col1, #T_229a9_row63_col0, #T_229a9_row63_col1, #T_229a9_row64_col0, #T_229a9_row64_col1, #T_229a9_row65_col0, #T_229a9_row65_col1, #T_229a9_row66_col0, #T_229a9_row66_col1, #T_229a9_row67_col0, #T_229a9_row67_col1, #T_229a9_row68_col0, #T_229a9_row68_col1, #T_229a9_row69_col0, #T_229a9_row69_col1, #T_229a9_row70_col0, #T_229a9_row70_col1, #T_229a9_row71_col0, #T_229a9_row71_col1, #T_229a9_row72_col0, #T_229a9_row72_col1, #T_229a9_row73_col0, #T_229a9_row73_col1, #T_229a9_row74_col0, #T_229a9_row74_col1, #T_229a9_row75_col0, #T_229a9_row75_col1, #T_229a9_row76_col0, #T_229a9_row76_col1, #T_229a9_row77_col0, #T_229a9_row77_col1, #T_229a9_row78_col0, #T_229a9_row78_col1, #T_229a9_row79_col0, #T_229a9_row79_col1, #T_229a9_row80_col0, #T_229a9_row80_col1, #T_229a9_row81_col0, #T_229a9_row81_col1, #T_229a9_row82_col0, #T_229a9_row82_col1, #T_229a9_row83_col0, #T_229a9_row83_col1, #T_229a9_row84_col0, #T_229a9_row84_col1, #T_229a9_row85_col0, #T_229a9_row85_col1, #T_229a9_row86_col0, #T_229a9_row86_col1, #T_229a9_row87_col0, #T_229a9_row87_col1, #T_229a9_row88_col0, #T_229a9_row88_col1, #T_229a9_row89_col0, #T_229a9_row89_col1, #T_229a9_row90_col0, #T_229a9_row90_col1, #T_229a9_row91_col0, #T_229a9_row91_col1, #T_229a9_row92_col0, #T_229a9_row92_col1, #T_229a9_row93_col0, #T_229a9_row93_col1, #T_229a9_row94_col0, #T_229a9_row94_col1, #T_229a9_row95_col0, #T_229a9_ ...

# %% [markdown]
# ________________________________
# ________________________________

# %% [markdown]
# ## Step 4: Do some quick tests to see that you can access and use the OpenAI text embedding model
# - To get an embedding, send your text string to the embeddings API endpoint, along with the embedding model name (e.g. **"text-embedding-3-small"**). The response will contain an embedding vector (list of floating point numbers), which you can extract, save in a vector database, and use for many different use cases. In our case, we'll not set up a vector database. We'll stick to a dataframe:

# %%
# Always follow OpenAI's latest documentation:
client = openai.OpenAI(api_key = api_key)
response = client.embeddings.create(
        input="Cybersecurity",
        model="text-embedding-3-small"
    )
print(response.data[0].embedding)
# Out:
# [0.006939577404409647, -0.008407317101955414, 0.030230291187763214, 0.02412758395075798, 0.04843541607260704, -0.009173374623060226, 0.003312070854008198, 0.04418669641017914, -0.004145721439272165, 0.02621331997215748, 0.039268478751182556, -0.025749823078513145, -0.029174549505114555, -0.058452095836400986, -0.005629554856568575, -0.004725092556327581, -0.06962752342224121, -0.0044386256486177444, 0.004400000907480717, 0.010673301294445992, 0.04925940930843353, 0.011497295461595058, 0.033294521272182465, 0.03401551768183708, -0.018964745104312897, 0.01906774379312992, 0.033603519201278687, -0.010525239631533623, 0.018012000247836113, -0.0031173378229141235, 0.046298179775476456, -0.05422912538051605, -0.015552893280982971, -0.00456093717366457, 0.013338408432900906, 0.039268478751182556, -0.010422240942716599, 0.010344991460442543, 0.02036811038851738, 0.04477894306182861, -0.015269644558429718, 0.01915786787867546, -0.022325096651911736, 0.052272140979766846, -0.013737530447542667, -0.020934605970978737, -0.020780107006430626, -0.0726659968495369, 0.017419755458831787, 0.03597250208258629, -0.015565767884254456, -0.018295248970389366, 0.013879154808819294, 0.07235699892044067, -0.03489100933074951, 0.0272175632417202, -0.0039236294105648994, 0.01949261501431465, -0.028711052611470222, 0.022415220737457275, 0.014085153117775917, -0.043568700551986694, -0.01463877409696579, -0.030513539910316467, 0.00635698763653636, -0.03561200574040413, -0.0007596197538077831, -0.002872714539989829, -0.013634530827403069, -0.017329631373286247, 0.047482673078775406, 0.05664961040019989, -0.016441261395812035, 0.0005829920992255211, 0.010486614890396595, 0.01445852592587471, 0.009108999744057655, 0.013299783691763878, 0.05250388756394386, -0.019119244068861008, 0.006714266259223223, -0.008040382526814938, 0.035869501531124115, -0.021694226190447807, -0.06864903122186661, -0.02997279353439808, -0.08919738978147507, -0.02706306427717209, -0.03167228028178215, 0.019312366843223572, 0.02381858602166176, 0.06803103536367416, -0.03558625653386116, 0.020265109837055206, -0.016235264018177986, 0.014600149355828762, 0.033809516578912735, 0.0021163136698305607, -0.0037916614674031734, 0.0031334315426647663, -0.016904758289456367, -0.055413618683815, -0.0375174917280674, -0.0003413863305468112, -0.005545868072658777, -0.012301977723836899, 0.04913066327571869, -0.033655017614364624, 0.004943965934216976, -0.01077630091458559, -0.06210857257246971, -0.028196055442094803, -0.02488720417022705, 0.04421244561672211, 0.010480177588760853, -0.019247991964221, 0.026445068418979645, -0.01378902979195118, 0.0010653989156708121, -0.018591372296214104, -0.004290564451366663, -0.002554060658439994, 0.010988736525177956, -0.0253378264605999, -0.018771620467305183, -0.007673447020351887, -0.07374749332666397, -0.00714557571336627, -0.0361270010471344, -0.03247052803635597, 0.039088230580091476, -0.05505312234163284, 0.014419901184737682, 0.008143381215631962, 0.03646174818277359, 0.02569832280278206, 0.012353477068245411, -0.018835995346307755, -0.01700775884091854, -0.03715699538588524, 0.02258259430527687, 0.02179722487926483, 0.06504405289888382, 0.02876255288720131, -0.020110610872507095, -0.059482090175151825, -0.06818553060293198, 0.040504470467567444, 0.015681641176342964, 0.03342327103018761, -0.00609948905184865, -0.019299492239952087, -0.01978873834013939, 0.05198889225721359, 0.01821799948811531, 0.0042841266840696335, 0.02961229532957077, 0.05834909901022911, -0.022209221497178078, -0.033268772065639496, -0.028196055442094803, 0.05088165029883385, -0.04992890730500221, -0.0031801031436771154, 0.024900078773498535, -0.033809516578912735, 0.01864287257194519, -0.008117632009088993, -0.027938557788729668, -0.011896418407559395, -0.005574836861342192, -0.0028984644450247288, 0.020831607282161713, 0.03810973837971687, -0.02788705751299858, 0.03417001664638519, 0.017509879544377327, 0.006057645659893751, 0.032599274069070816, -0.059585090726614, 0.029766794294 ...

# %% [markdown]
# ### For fun, do create some text embeddings and do similarity checks

# %%
# Function to fetch embeddings
openai.api_key = api_key
def get_embedding(text):
    client = openai.OpenAI(api_key = api_key)
    response = openai.embeddings.create(
        input=text,
        model="text-embedding-3-small"
    )
    return np.array(response.data[0].embedding)

# Embeddings
embed_cybersecurity = get_embedding("Cybersecurity")
embed_network_security = get_embedding("Network Security")
embed_pancake = get_embedding("Pancake")

# Function to calculate cosine similarity
def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

# Calculating similarities
similarity_cybersecurity_network = cosine_similarity(embed_cybersecurity, embed_network_security)
similarity_cybersecurity_pancake = cosine_similarity(embed_cybersecurity, embed_pancake)

print("Similarity between 'Cybersecurity' and 'Network Security':", similarity_cybersecurity_network)
print("Similarity between 'Cybersecurity' and 'Pancake':", similarity_cybersecurity_pancake)
# Out:
# Similarity between 'Cybersecurity' and 'Network Security': 0.6221389041946319
# Similarity between 'Cybersecurity' and 'Pancake': 0.1060238888846225

# %% [markdown]
# _________________________________
# _________________________________

# %% [markdown]
# # Step 5: Use the text embedding model to convert your SMS data into vectors!
# ## Caution: Only run the code below once and then store your embedding data into a csv file for later reuse!
# ## Running the code below can take some time, and you will incur a cost each time you use the embedding model.

# %%
def generate_embeddings(texts, api_key):
    client = openai.OpenAI(api_key=api_key)
    embeddings = []
    for text in texts:
        response = client.embeddings.create(
            input=text, 
            model="text-embedding-3-small"
        )
        # Correctly accessing the response object
        embeddings.append(response.data[0].embedding)
    return embeddings

# Generate embeddings for all messages
embeddings = generate_embeddings(spam_data_cleaned['message'].tolist(), api_key)

# Create DataFrame with embeddings
column_names = ["embedding_" + str(i) for i in range(1536)]  # Assuming 1536 dimensions from the model
df_embeddings = pd.DataFrame(embeddings, columns=column_names)
df_embeddings['label'] = spam_data_cleaned['label']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_embeddings.drop('label', axis=1), df_embeddings['label'], test_size=0.2, random_state=42)

# Now X_train, X_test, y_train, and y_test are ready for model training and evaluation

# Save the contents of df_embeddings to a csv file for later use:
df_embeddings.to_csv('sms_embeddings_backup.csv', index=False)

# %% [markdown]
# ### Assuming you have saved your vector embeddings (using the code above) to a csv file, let's now reload that data and prepare to train our machine learning model (classifier).

# %%
df_embeddings_backup = pd.read_csv('sms_embeddings_backup.csv')
df_embeddings_backup.head(3)
# Out:
#    embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# 0 -0.011584     0.015810    -0.017551    -0.014157    -0.071270
# 1  0.062310     0.004907     0.009618     0.041285     0.016471
# 2 -0.005321    -0.017714     0.059229    -0.022827    -0.008559
#
#    embedding_5  embedding_6  embedding_7  embedding_8  embedding_9  ...  \
# 0 -0.058155     0.023791     0.018771    -0.026714    -0.057697     ...
# 1  0.021203    -0.012193    -0.011859    -0.046792    -0.014219     ...
# 2 -0.027123    -0.002243     0.044850    -0.027201     0.016300     ...
#
#    embedding_1527  embedding_1528  embedding_1529  embedding_1530  \
# 0 -0.012315        0.017525        0.020995        0.027959
# 1 -0.016293       -0.035398        0.019975        0.035660
# 2  0.007423        0.005574        0.039737       -0.025955
#
#    embedding_1531  embedding_1532  embedding_1533  embedding_1534  \
# 0  0.013319        0.019305        0.021986       -0.006850
# 1  0.040094        0.020714       -0.021167       -0.037996
# 2  0.002675       -0.027694        0.006988        0.019233
#
#    embedding_1535  label
# 0  0.000139         ham
# 1  0.014791         ham
# 2  0.017078        spam
#
# [3 rows x 1537 columns]

# %% [markdown]
# _______________________________
# _______________________________

# %% [markdown]
# ## Train the Spam Classifier

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_embeddings_backup.drop('label', axis=1), df_embeddings_backup['label'], test_size=0.2, random_state=42)

# %%
# Check your training set. 
X_train
# Out:
#       embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# 1978  0.029612     0.043706    -0.069668     0.017441    -0.006086
# 3989  0.039462    -0.055224     0.025769     0.036873    -0.019576
# 3935  0.040620    -0.018699     0.028650     0.017906    -0.002226
# 4078  0.001870    -0.004188    -0.030621     0.005145     0.000733
# 4086  0.015200    -0.018024     0.013840     0.007519    -0.019044
# ...           ...          ...          ...          ...          ...
# 3772 -0.012782    -0.026929    -0.039419    -0.016106    -0.032256
# 5191  0.026796    -0.007993    -0.041911    -0.028392    -0.041259
# 5226  0.065759    -0.034094     0.013380     0.017594    -0.011988
# 5390 -0.014606     0.013743    -0.028760     0.044467    -0.011070
# 860  -0.040971     0.026691    -0.036595    -0.027126     0.002588
#
#       embedding_5  embedding_6  embedding_7  embedding_8  embedding_9  ...  \
# 1978 -0.002881     0.022131     0.003931     0.009440     0.006944     ...
# 3989 -0.000387     0.023517     0.061361    -0.016410    -0.029076     ...
# 3935  0.020384     0.021884     0.092839     0.010056     0.016555     ...
# 4078  0.019830    -0.003468     0.055934    -0.043165     0.052729     ...
# 4086 -0.049888     0.003665     0.062575     0.029395    -0.043353     ...
# ...           ...          ...          ...          ...          ...  ...
# 3772 -0.030488     0.010459    -0.005557     0.007885    -0.036666     ...
# 5191 -0.010956    -0.013205     0.024862     0.004250    -0.004365     ...
# 5226 -0.016594    -0.004434     0.042879    -0.040831    -0.035332     ...
# 5390  0.011342     0.003157     0.013730    -0.009034     0.002312     ...
# 860  -0.009392    -0.009181     0.008195     0.025808    -0.029122     ...
#
#       embedding_1526  embedding_1527  embedding_1528  embedding_1529  \
# 1978 -0.013573       -0.018589        0.010860        0.017502
# 3989 -0.008578        0.020097        0.026627       -0.000094
# 3935  0.001345       -0.017472        0.038811        0.020546
# 4078  0.000757        0.016963       -0.044116       -0.024625
# 4086 -0.012834        0.049770       -0.012679        0.018009
# ...              ...             ...             ...             ...
# 3772 -0.021478       -0.001121       -0.027533       -0.013386
# 5191  0.003679        0.038671        0.015599        0.023241
# 5226  0.000429        0.014464       -0.016487       -0.019904
# 5390 -0.046696        0.024329       -0.012483       -0.014579
# 860   0.016775        0.007959       -0.041047       -0.017402
#
#       embedding_1530  embedding_1531  embedding_1532  embedding_1533  \
# 1978  0.025116       -0.000050       -0.022530       -0.001372
# 3989 -0.010006        0.007487       -0.017958        0.011561
# 3935  0.007745       -0.019207        0.001444       -0.003776
# 4078  0.043390        0.010641       -0.021032        0.022534
# 4086 -0.016605        0.050805       -0.008827       -0.032204
# ...              ...             ...             ...             ...
# 3772  0.038591        0.032570       -0.022541       -0.010963
# 5191 -0.023991        0.048320       -0.003709        0.014765
# 5226  0.020999        0.012857        0.002088        0.019154
# 5390  0.014911        0.027195       -0.004338       -0.022114
# 860   0.040356       -0.006564        0.011548        0.010076
#
#       embedding_1534  embedding_1535
# 1978 -0.026784       -0.025672
# 3989  0.030033       -0.009183
# 3935 -0.005514       -0.002480
# 4078  0.016963        0.016337
# 4086  0.001163        0.014964
# ...              ...             ...
# 3772  0.004066       -0.002163
# 5191 -0.006983       -0.000349
# 5226  0.020844       -0.009404
# 5390 -0.012987        0.043910
# 860  -0.002538       -0.025450
#
# [4457 rows x 1536 columns]

# %%
# Check your training set. 
y_train
# Out:
# 1978     ham
# 3989    spam
# 3935     ham
# 4078     ham
# 4086    spam
#         ...
# 3772     ham
# 5191     ham
# 5226     ham
# 5390     ham
# 860      ham
# Name: label, Length: 4457, dtype: object

# %%
# Create the Random Forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.979372197309417
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       965
#         spam       1.00      0.85      0.92       150
#
#     accuracy                           0.98      1115
#    macro avg       0.99      0.92      0.95      1115
# weighted avg       0.98      0.98      0.98      1115
#
# Confusion Matrix:
# [[965   0]
#  [ 23 127]]

# %% [markdown]
# ## Optional: Improve the visualisation/display of the Confusion Matrix

# %%
# Assuming y_test are the true labels and y_pred are the labels predicted by the model
cm = confusion_matrix(y_test, y_pred)

# Initialize the ConfusionMatrixDisplay object with the confusion matrix
cmd = ConfusionMatrixDisplay(cm, display_labels=['Ham', 'Spam'])

# Plot the matrix
cmd.plot(cmap=plt.cm.Blues, values_format='.0f')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Optional: Reduce the dimensionality of the 1536-dimensional vectors to 2, and plot on a 2D graph.

# %%
# Apply PCA to reduce to two dimensions
pca = PCA(n_components=2)
X_test_reduced = pca.fit_transform(X_test)

# Convert y_test to colors: 'spam' will be red, 'ham' will be blue
colors = ['red' if label == 'spam' else 'blue' for label in y_test]

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X_test_reduced[:, 0], X_test_reduced[:, 1], c=colors, alpha=0.5, marker='o')
plt.title('2D PCA of SMS Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()
